# %% [markdown]
# ### Importation des données

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xgboost as xgb
import seaborn as sns
import yaml
import importlib

import utils

# %%
importlib.reload(utils)
# Out:
# <module 'utils' from '/home/alexandre-tonon/SDD/Hackathons/Hackathon_Heart_Rate_Los_Tigros/utils.py'>

# %%
df_train = pd.read_csv("data/train.csv")
df_test = pd.read_csv("data/test.csv")

# %%
X_train,y_train, features_99, scaler = utils.data_processing_train(df_train)
print(X_train.head())
print(y_train.head())
# Out:
# Feature: PHYSHLTH
# ['1 - 30', '77', '88', '99', 'BLANK']
# Feature: MENTHLTH
# ['1 - 30', '77', '88', '99', 'BLANK']
# Feature: POORHLTH
# ['1 - 30', '77', '88', '99', 'BLANK']
# Feature: SLEPTIM1
# ['1 - 24', '77', '99', 'BLANK']
# Feature: WEIGHT2
# ['50 - 0776', '7777', '9023 - 9352', '9999', 'BLANK']
# Feature: HEIGHT3
# ['200 - 711', '7777', '9061 - 9998', '9999', 'BLANK']
# Feature: MARIJAN1
# ['1 - 30', '77', '88', '99', 'BLANK']
# Feature: ALCDAY4
# ['101 - 199', '201 - 299', '777', '888', '999', 'BLANK']
# Feature: AVEDRNK3
# ['1 - 76', '77', '88', '99', 'BLANK']
# Feature: DRNK3GE5
# ['1 - 76', '77', '88', '99', 'BLANK']
# Feature: MAXDRNKS
# ['0', '1 - 76', '77', '99', 'BLANK']
# Feature: COPDSMOK
# ['1 - 76', '77', '88', '99', 'BLANK']
# Feature: _PACKDAY
# ['0 - 100', 'BLANK']
# Nombre de features conservées : 63
# Features conservées : ['CVDSTRK3', 'CHCKDNY2', 'DIABETE4', 'DIFFDRES', 'VETERAN3', 'CHCCOPD3', 'LCSCTSC1', 'DIFFWALK', 'COLNCNCR', 'CHCOCNC1', 'ADDEPEV3', '_HCVU652', '_SEX', 'CHCSCNC1', 'GENHLTH', '_AGEG5YR', 'EXERANY2', 'HIVRISK5', '_ASTHMS1', 'CHECKUP1', 'DIFFALON', 'MEDCOST1', 'USENOW3', 'LCSSCNCR', 'SDHEMPLY', '_FLSHOT7', '_PNEUMO3', '_SMOKGRP', 'POORHLTH', 'COVIDPOS', 'HADHYST2', 'PERSDOC3', 'PRIMINSR', 'COLNSIGM', '_RFHLTH', 'MARIJAN1', 'DRNK3GE5', 'PHYSHLTH', '_PHYS14D', 'ECIGNOW2', 'PREDIAB2', '_PACKDAY', '_LCSREC', 'ALCDAY4', '_TOTINDA', 'MAXDRNKS', 'CERVSCRN', 'SDHISOLT', 'COPDSMOK', 'MENTHLTH', 'COVIDSMP', '_MENT14D', 'SLEPTIM1', 'AVEDRNK3', 'CRVCLPAP', 'PDIABTS1', 'VIRCOLO1', '_STATE', 'CRVCLHPV', 'STOOLDN2', 'WEIGHT2', 'HEIGHT3', 'SMALSTOL']
#     CVDSTRK3  CHCKDNY2  DIABETE4  DIFFDRES  VETERAN3  CHCCOPD3  LCSCTSC1  \
# ID
# 0          2         1         3         2         2         2         1
# 1          2         2         3         2         2         2         0
# 2          2         2         3         2         2         2         1
# 3          2         2         3         2         2         2         2
# 4          2         2         3         2         2         2         2
#
#     DIFFWALK  COLNCNCR  CHCOCNC1  ...  AVEDRNK3  CRVCLPAP  PDIABTS1  VIRCOLO1  \
# ID                                ...
# 0          2         1         1  ... -0.695932         0         1         1
# 1          2         0         2  ... -0.069959         1         0         0
# 2          2         0         2  ... -0.069959         0         1         0
# 3          2         1         2  ... -0.069959         0         0         2
# 4          2         0         2  ...  1.181988         0         0         0
#
#     _STATE  CRVCLHPV  STOOLDN2   WEIGHT2   HEIGHT3  SMALSTOL
# ID
# 0        1         0         2 -0.383793 -1.206917         1
# 1        6         3         0 -0.863220 -1.206917         0
# 2       15         0         0  2.231264  0.950560         0
# 3       35         0         2  1.359578  1.190280         1
# 4       21         0         0 -0.056911  1.429999         0
#
# [5 rows x 63 columns]
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: TARGET, dtype: bool

# %%
X_test = utils.data_processing_test(df_test,features_99, scaler)
print(X_test.head())
# Out:
# Feature: PHYSHLTH
# ['1 - 30', '77', '88', '99', 'BLANK']
# Feature: MENTHLTH
# ['1 - 30', '77', '88', '99', 'BLANK']
# Feature: POORHLTH
# ['1 - 30', '77', '88', '99', 'BLANK']
# Feature: SLEPTIM1
# ['1 - 24', '77', '99', 'BLANK']
# Feature: WEIGHT2
# ['50 - 0776', '7777', '9023 - 9352', '9999', 'BLANK']
# Feature: HEIGHT3
# ['200 - 711', '7777', '9061 - 9998', '9999', 'BLANK']
# Feature: MARIJAN1
# ['1 - 30', '77', '88', '99', 'BLANK']
# Feature: ALCDAY4
# ['101 - 199', '201 - 299', '777', '888', '999', 'BLANK']
# Feature: AVEDRNK3
# ['1 - 76', '77', '88', '99', 'BLANK']
# Feature: DRNK3GE5
# ['1 - 76', '77', '88', '99', 'BLANK']
# Feature: MAXDRNKS
# ['0', '1 - 76', '77', '99', 'BLANK']
# Feature: COPDSMOK
# ['1 - 76', '77', '88', '99', 'BLANK']
# Feature: _PACKDAY
# ['0 - 100', 'BLANK']
#         CVDSTRK3  CHCKDNY2  DIABETE4  DIFFDRES  VETERAN3  CHCCOPD3  LCSCTSC1  \
# ID
# 225000         2         2         3         0         2         2         0
# 225001         2         2         1         1         4         2         2
# 225002         2         2         1         2         2         2         1
# 225003         2         2         3         2         2         2         2
# 225004         2         2         3         2         1         1         1
#
#         DIFFWALK  COLNCNCR  CHCOCNC1  ...  AVEDRNK3  CRVCLPAP  PDIABTS1  \
# ID                                    ...
# 225000         0         0         2  ... -0.065995         0         0
# 225001         1         0         2  ... -0.065995         0         0
# 225002         2         0         2  ... -0.668876         0         0
# 225003         2         2         2  ... -0.065995         1         0
# 225004         2         2         2  ... -0.065995         0         1
#
#         VIRCOLO1  _STATE  CRVCLHPV  STOOLDN2   WEIGHT2   HEIGHT3  SMALSTOL
# ID
# 225000         0       4         0         0 -0.376217  0.223355         0
# 225001         0      35         0         0  4.182952  0.909025         0
# 225002         0       9         0         0  1.002137  1.594695         0
# 225003         0      30         3         0 -0.312600 -1.147985         0
# 225004         0       1         0         0  1.956381  2.051808         0
#
# [5 rows x 63 columns]

# %%
from sklearn.model_selection import train_test_split

X_train_train, X_train_test, y_train_train, y_train_test =  train_test_split(X_train, y_train, test_size = 0.2)

# %%
from xgboost import XGBClassifier
from sklearn.metrics import f1_score
import xgboost as xgb

max_depth = [1, 2, 5, 10, 15, 20, 50, 100]
min_child_weight = [1, 5, 10, 50, 100, 500, 1000]
eta = [0.01, 0.1, 0.2, 0.3, 0.5, 1]
threshold = [0.01, 0.05, 0.12, 0.15, 0.2, 0.3, 0.5]

dtrain = xgb.DMatrix(X_train_train, label=y_train_train)
dtest = xgb.DMatrix(X_train_test, label=y_train_test)

best_param = {}
best_f1 = -1
for md in max_depth:
    for mcw in min_child_weight:
        for e in eta:
            params = {
                'objective': 'binary:logistic',
                'eval_metric': 'logloss',
                'eta': e,
                'max_depth': md,
                'min_child_weight': mcw,
            }
            model = xgb.train(params, dtrain)
            y_pred = model.predict(dtest)
            for t in threshold:
                y_pred_binary = [1 if pred > t else 0 for pred in y_pred]
                f1 = f1_score(y_train_test, y_pred_binary)
                if f1 > best_f1:
                    best_f1 = f1
                    best_param = {
                        'max_depth': md,
                        'min_child_weight': mcw,
                        'eta': e,
                        'threshold': t
                    }
                print(f"max_depth: {md}, min_child_weight: {mcw}, eta: {e}, threshold: {t} => F1 Score: {f1}")

print("Best Parameters:", best_param)
print("Best F1 Score:", best_f1)


model = xgb.train(best_param, dtrain)

y_pred = model.predict(dtest)
y_pred_binary = [1 if pred > best_param['threshold'] else 0 for pred in y_pred]
f1 = f1_score(y_train_test, y_pred_binary)
print(f"F1 Score: {f1}")

y_pred = model.predict(dtest)

submission = pd.read_csv("data/sample_submission.csv")
dsubmission = submission.drop(columns=['TARGET'])
dsubmission = xgb.DMatrix(X_test)
y_pred = model.predict(dsubmission)
submission['TARGET'] = y_pred

submission['TARGET'] = submission['TARGET'].apply(lambda x: 1 if x > best_param['threshold'] else 0)
submission.to_csv("submission_de_bg.csv", index=False)
# Out:
# max_depth: 1, min_child_weight: 1, eta: 0.01, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 1, eta: 0.01, threshold: 0.05 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 1, eta: 0.01, threshold: 0.12 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 1, eta: 0.01, threshold: 0.15 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 1, eta: 0.01, threshold: 0.2 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 1, eta: 0.01, threshold: 0.3 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 1, eta: 0.01, threshold: 0.5 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 1, eta: 0.1, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 1, eta: 0.1, threshold: 0.05 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 1, eta: 0.1, threshold: 0.12 => F1 Score: 0.3844541203031769
# max_depth: 1, min_child_weight: 1, eta: 0.1, threshold: 0.15 => F1 Score: 0.31474386263658294
# max_depth: 1, min_child_weight: 1, eta: 0.1, threshold: 0.2 => F1 Score: 0.09689495705791676
# max_depth: 1, min_child_weight: 1, eta: 0.1, threshold: 0.3 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 1, eta: 0.1, threshold: 0.5 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 1, eta: 0.2, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 1, eta: 0.2, threshold: 0.05 => F1 Score: 0.21759752717970582
# max_depth: 1, min_child_weight: 1, eta: 0.2, threshold: 0.12 => F1 Score: 0.3797250859106529
# max_depth: 1, min_child_weight: 1, eta: 0.2, threshold: 0.15 => F1 Score: 0.3756008973400278
# max_depth: 1, min_child_weight: 1, eta: 0.2, threshold: 0.2 => F1 Score: 0.2515918086387885
# max_depth: 1, min_child_weight: 1, eta: 0.2, threshold: 0.3 => F1 Score: 0.048599861143253875
# max_depth: 1, min_child_weight: 1, eta: 0.2, threshold: 0.5 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 1, eta: 0.3, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 1, eta: 0.3, threshold: 0.05 => F1 Score: 0.239600466521128
# max_depth: 1, min_child_weight: 1, eta: 0.3, threshold: 0.12 => F1 Score: 0.36446189716529637
# max_depth: 1, min_child_weight: 1, eta: 0.3, threshold: 0.15 => F1 Score: 0.3877280265339967
# max_depth: 1, min_child_weight: 1, eta: 0.3, threshold: 0.2 => F1 Score: 0.34716406547392464
# max_depth: 1, min_child_weight: 1, eta: 0.3, threshold: 0.3 => F1 Score: 0.20072229614141798
# max_depth: 1, min_child_weight: 1, eta: 0.3, threshold: 0.5 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 1, eta: 0.5, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 1, eta: 0.5, threshold: 0.05 => F1 Score: 0.2729608899214982
# max_depth: 1, min_child_weight: 1, eta: 0.5, threshold: 0.12 => F1 Score: 0.3837101490621211
# max_depth: 1, min_child_weight: 1, eta: 0.5, threshold: 0.15 => F1 Score: 0.39815281276238457
# max_depth: 1, min_child_weight: 1, eta: 0.5, threshold: 0.2 => F1 Score: 0.3854380468834396
# max_depth: 1, min_child_weight: 1, eta: 0.5, threshold: 0.3 => F1 Score: 0.3091190108191654
# max_depth: 1, min_child_weight: 1, eta: 0.5, threshold: 0.5 => F1 Score: 0.08489722966934764
# max_depth: 1, min_child_weight: 1, eta: 1, threshold: 0.01 => F1 Score: 0.18629593745071088
# max_depth: 1, min_child_weight: 1, eta: 1, threshold: 0.05 => F1 Score: 0.3080095963634833
# max_depth: 1, min_child_weight: 1, eta: 1, threshold: 0.12 => F1 Score: 0.3933858040291718
# max_depth: 1, min_child_weight: 1, eta: 1, threshold: 0.15 => F1 Score: 0.3999332888592395
# max_depth: 1, min_child_weight: 1, eta: 1, threshold: 0.2 => F1 Score: 0.38837599664288713
# max_depth: 1, min_child_weight: 1, eta: 1, threshold: 0.3 => F1 Score: 0.3571719364907043
# max_depth: 1, min_child_weight: 1, eta: 1, threshold: 0.5 => F1 Score: 0.20077369439071566
# max_depth: 1, min_child_weight: 5, eta: 0.01, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 5, eta: 0.01, threshold: 0.05 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 5, eta: 0.01, threshold: 0.12 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 5, eta: 0.01, threshold: 0.15 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 5, eta: 0.01, threshold: 0.2 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 5, eta: 0.01, threshold: 0.3 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 5, eta: 0.01, threshold: 0.5 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 5, eta: 0.1, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 5, eta: 0.1, threshold: 0.05 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 5, eta: 0.1, threshold: 0.12 => F1 Score: 0.3844541203031769
# max_depth: 1, min_child_weight: 5, eta: 0.1, threshold: 0.15 => F1 Score: 0.31474386263658294
# max_depth: 1, min_child_weight: 5, eta: 0.1, threshold: 0.2 => F1 Score: 0.09689495705791676
# max_depth: 1, min_child_weight: 5, eta: 0.1, threshold: 0.3 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 5, eta: 0.1, threshold: 0.5 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 5, eta: 0.2, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 5, eta: 0.2, threshold: 0.05 => F1 Score: 0.21759752717970582
# max_depth: 1, min_child_weight: 5, eta: 0.2, threshold: 0.12 => F1 Score: 0.3797250859106529
# max_depth: 1, min_child_weight: 5, eta: 0.2, threshold: 0.15 => F1 Score: 0.3756008973400278
# max_depth: 1, min_child_weight: 5, eta: 0.2, threshold: 0.2 => F1 Score: 0.2515918086387885
# max_depth: 1, min_child_weight: 5, eta: 0.2, threshold: 0.3 => F1 Score: 0.048599861143253875
# max_depth: 1, min_child_weight: 5, eta: 0.2, threshold: 0.5 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 5, eta: 0.3, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 5, eta: 0.3, threshold: 0.05 => F1 Score: 0.239600466521128
# max_depth: 1, min_child_weight: 5, eta: 0.3, threshold: 0.12 => F1 Score: 0.36446189716529637
# max_depth: 1, min_child_weight: 5, eta: 0.3, threshold: 0.15 => F1 Score: 0.3877280265339967
# max_depth: 1, min_child_weight: 5, eta: 0.3, threshold: 0.2 => F1 Score: 0.34716406547392464
# max_depth: 1, min_child_weight: 5, eta: 0.3, threshold: 0.3 => F1 Score: 0.20072229614141798
# max_depth: 1, min_child_weight: 5, eta: 0.3, threshold: 0.5 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 5, eta: 0.5, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 5, eta: 0.5, threshold: 0.05 => F1 Score: 0.2729608899214982
# max_depth: 1, min_child_weight: 5, eta: 0.5, threshold: 0.12 => F1 Score: 0.3837101490621211
# max_depth: 1, min_child_weight: 5, eta: 0.5, threshold: 0.15 => F1 Score: 0.39815281276238457
# max_depth: 1, min_child_weight: 5, eta: 0.5, threshold: 0.2 => F1 Score: 0.3854380468834396
# max_depth: 1, min_child_weight: 5, eta: 0.5, threshold: 0.3 => F1 Score: 0.3091190108191654
# max_depth: 1, min_child_weight: 5, eta: 0.5, threshold: 0.5 => F1 Score: 0.08489722966934764
# max_depth: 1, min_child_weight: 5, eta: 1, threshold: 0.01 => F1 Score: 0.18629593745071088
# max_depth: 1, min_child_weight: 5, eta: 1, threshold: 0.05 => F1 Score: 0.3080095963634833
# max_depth: 1, min_child_weight: 5, eta: 1, threshold: 0.12 => F1 Score: 0.3933858040291718
# max_depth: 1, min_child_weight: 5, eta: 1, threshold: 0.15 => F1 Score: 0.3999332888592395
# max_depth: 1, min_child_weight: 5, eta: 1, threshold: 0.2 => F1 Score: 0.38837599664288713
# max_depth: 1, min_child_weight: 5, eta: 1, threshold: 0.3 => F1 Score: 0.3571719364907043
# max_depth: 1, min_child_weight: 5, eta: 1, threshold: 0.5 => F1 Score: 0.20077369439071566
# max_depth: 1, min_child_weight: 10, eta: 0.01, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 10, eta: 0.01, threshold: 0.05 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 10, eta: 0.01, threshold: 0.12 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 10, eta: 0.01, threshold: 0.15 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 10, eta: 0.01, threshold: 0.2 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 10, eta: 0.01, threshold: 0.3 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 10, eta: 0.01, threshold: 0.5 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 10, eta: 0.1, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 10, eta: 0.1, threshold: 0.05 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 10, eta: 0.1, threshold: 0.12 => F1 Score: 0.3844541203031769
# max_depth: 1, min_child_weight: 10, eta: 0.1, threshold: 0.15 => F1 Score: 0.31474386263658294
# max_depth: 1, min_child_weight: 10, eta: 0.1, threshold: 0.2 => F1 Score: 0.09689495705791676
# max_depth: 1, min_child_weight: 10, eta: 0.1, threshold: 0.3 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 10, eta: 0.1, threshold: 0.5 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 10, eta: 0.2, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 10, eta: 0.2, threshold: 0.05 => F1 Score: 0.21759752717970582
# max_depth: 1, min_child_weight: 10, eta: 0.2, threshold: 0.12 => F1 Score: 0.3797250859106529
# max_depth: 1, min_child_weight: 10, eta: 0.2, threshold: 0.15 => F1 Score: 0.3756008973400278
# max_depth: 1, min_child_weight: 10, eta: 0.2, threshold: 0.2 => F1 Score: 0.2515918086387885
# max_depth: 1, min_child_weight: 10, eta: 0.2, threshold: 0.3 => F1 Score: 0.048599861143253875
# max_depth: 1, min_child_weight: 10, eta: 0.2, threshold: 0.5 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 10, eta: 0.3, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 10, eta: 0.3, threshold: 0.05 => F1 Score: 0.239600466521128
# max_depth: 1, min_child_weight: 10, eta: 0.3, threshold: 0.12 => F1 Score: 0.36446189716529637
# max_depth: 1, min_child_weight: 10, eta: 0.3, threshold: 0.15 => F1 Score: 0.3877280265339967
# max_depth: 1, min_child_weight: 10, eta: 0.3, threshold: 0.2 => F1 Score: 0.34716406547392464
# max_depth: 1, min_child_weight: 10, eta: 0.3, threshold: 0.3 => F1 Score: 0.20072229614141798
# max_depth: 1, min_child_weight: 10, eta: 0.3, threshold: 0.5 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 10, eta: 0.5, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 10, eta: 0.5, threshold: 0.05 => F1 Score: 0.2729608899214982
# max_depth: 1, min_child_weight: 10, eta: 0.5, threshold: 0.12 => F1 Score: 0.3837101490621211
# max_depth: 1, min_child_weight: 10, eta: 0.5, threshold: 0.15 => F1 Score: 0.39815281276238457
# max_depth: 1, min_child_weight: 10, eta: 0.5, threshold: 0.2 => F1 Score: 0.3854380468834396
# max_depth: 1, min_child_weight: 10, eta: 0.5, threshold: 0.3 => F1 Score: 0.3091190108191654
# max_depth: 1, min_child_weight: 10, eta: 0.5, threshold: 0.5 => F1 Score: 0.08489722966934764
# max_depth: 1, min_child_weight: 10, eta: 1, threshold: 0.01 => F1 Score: 0.18629593745071088
# max_depth: 1, min_child_weight: 10, eta: 1, threshold: 0.05 => F1 Score: 0.3080095963634833
# max_depth: 1, min_child_weight: 10, eta: 1, threshold: 0.12 => F1 Score: 0.3933858040291718
# max_depth: 1, min_child_weight: 10, eta: 1, threshold: 0.15 => F1 Score: 0.3999332888592395
# max_depth: 1, min_child_weight: 10, eta: 1, threshold: 0.2 => F1 Score: 0.38837599664288713
# max_depth: 1, min_child_weight: 10, eta: 1, threshold: 0.3 => F1 Score: 0.3571719364907043
# max_depth: 1, min_child_weight: 10, eta: 1, threshold: 0.5 => F1 Score: 0.20077369439071566
# max_depth: 1, min_child_weight: 50, eta: 0.01, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 50, eta: 0.01, threshold: 0.05 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 50, eta: 0.01, threshold: 0.12 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 50, eta: 0.01, threshold: 0.15 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 50, eta: 0.01, threshold: 0.2 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 50, eta: 0.01, threshold: 0.3 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 50, eta: 0.01, threshold: 0.5 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 50, eta: 0.1, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 50, eta: 0.1, threshold: 0.05 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 50, eta: 0.1, threshold: 0.12 => F1 Score: 0.3844541203031769
# max_depth: 1, min_child_weight: 50, eta: 0.1, threshold: 0.15 => F1 Score: 0.31474386263658294
# max_depth: 1, min_child_weight: 50, eta: 0.1, threshold: 0.2 => F1 Score: 0.09689495705791676
# max_depth: 1, min_child_weight: 50, eta: 0.1, threshold: 0.3 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 50, eta: 0.1, threshold: 0.5 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 50, eta: 0.2, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 50, eta: 0.2, threshold: 0.05 => F1 Score: 0.21759752717970582
# max_depth: 1, min_child_weight: 50, eta: 0.2, threshold: 0.12 => F1 Score: 0.3797250859106529
# max_depth: 1, min_child_weight: 50, eta: 0.2, threshold: 0.15 => F1 Score: 0.3756008973400278
# max_depth: 1, min_child_weight: 50, eta: 0.2, threshold: 0.2 => F1 Score: 0.2515918086387885
# max_depth: 1, min_child_weight: 50, eta: 0.2, threshold: 0.3 => F1 Score: 0.048599861143253875
# max_depth: 1, min_child_weight: 50, eta: 0.2, threshold: 0.5 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 50, eta: 0.3, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 50, eta: 0.3, threshold: 0.05 => F1 Score: 0.239600466521128
# max_depth: 1, min_child_weight: 50, eta: 0.3, threshold: 0.12 => F1 Score: 0.36446189716529637
# max_depth: 1, min_child_weight: 50, eta: 0.3, threshold: 0.15 => F1 Score: 0.3877280265339967
# max_depth: 1, min_child_weight: 50, eta: 0.3, threshold: 0.2 => F1 Score: 0.34716406547392464
# max_depth: 1, min_child_weight: 50, eta: 0.3, threshold: 0.3 => F1 Score: 0.20072229614141798
# max_depth: 1, min_child_weight: 50, eta: 0.3, threshold: 0.5 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 50, eta: 0.5, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 50, eta: 0.5, threshold: 0.05 => F1 Score: 0.2729608899214982
# max_depth: 1, min_child_weight: 50, eta: 0.5, threshold: 0.12 => F1 Score: 0.3837101490621211
# max_depth: 1, min_child_weight: 50, eta: 0.5, threshold: 0.15 => F1 Score: 0.39815281276238457
# max_depth: 1, min_child_weight: 50, eta: 0.5, threshold: 0.2 => F1 Score: 0.3854380468834396
# max_depth: 1, min_child_weight: 50, eta: 0.5, threshold: 0.3 => F1 Score: 0.3091190108191654
# max_depth: 1, min_child_weight: 50, eta: 0.5, threshold: 0.5 => F1 Score: 0.08489722966934764
# max_depth: 1, min_child_weight: 50, eta: 1, threshold: 0.01 => F1 Score: 0.18629593745071088
# max_depth: 1, min_child_weight: 50, eta: 1, threshold: 0.05 => F1 Score: 0.3080095963634833
# max_depth: 1, min_child_weight: 50, eta: 1, threshold: 0.12 => F1 Score: 0.3933858040291718
# max_depth: 1, min_child_weight: 50, eta: 1, threshold: 0.15 => F1 Score: 0.3999332888592395
# max_depth: 1, min_child_weight: 50, eta: 1, threshold: 0.2 => F1 Score: 0.38837599664288713
# max_depth: 1, min_child_weight: 50, eta: 1, threshold: 0.3 => F1 Score: 0.3571719364907043
# max_depth: 1, min_child_weight: 50, eta: 1, threshold: 0.5 => F1 Score: 0.20077369439071566
# max_depth: 1, min_child_weight: 100, eta: 0.01, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 100, eta: 0.01, threshold: 0.05 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 100, eta: 0.01, threshold: 0.12 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 100, eta: 0.01, threshold: 0.15 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 100, eta: 0.01, threshold: 0.2 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 100, eta: 0.01, threshold: 0.3 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 100, eta: 0.01, threshold: 0.5 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 100, eta: 0.1, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 100, eta: 0.1, threshold: 0.05 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 100, eta: 0.1, threshold: 0.12 => F1 Score: 0.3844541203031769
# max_depth: 1, min_child_weight: 100, eta: 0.1, threshold: 0.15 => F1 Score: 0.31474386263658294
# max_depth: 1, min_child_weight: 100, eta: 0.1, threshold: 0.2 => F1 Score: 0.09689495705791676
# max_depth: 1, min_child_weight: 100, eta: 0.1, threshold: 0.3 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 100, eta: 0.1, threshold: 0.5 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 100, eta: 0.2, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 100, eta: 0.2, threshold: 0.05 => F1 Score: 0.21759752717970582
# max_depth: 1, min_child_weight: 100, eta: 0.2, threshold: 0.12 => F1 Score: 0.3797250859106529
# max_depth: 1, min_child_weight: 100, eta: 0.2, threshold: 0.15 => F1 Score: 0.3756008973400278
# max_depth: 1, min_child_weight: 100, eta: 0.2, threshold: 0.2 => F1 Score: 0.2515918086387885
# max_depth: 1, min_child_weight: 100, eta: 0.2, threshold: 0.3 => F1 Score: 0.048599861143253875
# max_depth: 1, min_child_weight: 100, eta: 0.2, threshold: 0.5 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 100, eta: 0.3, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 100, eta: 0.3, threshold: 0.05 => F1 Score: 0.239600466521128
# max_depth: 1, min_child_weight: 100, eta: 0.3, threshold: 0.12 => F1 Score: 0.36446189716529637
# max_depth: 1, min_child_weight: 100, eta: 0.3, threshold: 0.15 => F1 Score: 0.3877280265339967
# max_depth: 1, min_child_weight: 100, eta: 0.3, threshold: 0.2 => F1 Score: 0.34716406547392464
# max_depth: 1, min_child_weight: 100, eta: 0.3, threshold: 0.3 => F1 Score: 0.20072229614141798
# max_depth: 1, min_child_weight: 100, eta: 0.3, threshold: 0.5 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 100, eta: 0.5, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 100, eta: 0.5, threshold: 0.05 => F1 Score: 0.2729608899214982
# max_depth: 1, min_child_weight: 100, eta: 0.5, threshold: 0.12 => F1 Score: 0.3837101490621211
# max_depth: 1, min_child_weight: 100, eta: 0.5, threshold: 0.15 => F1 Score: 0.39815281276238457
# max_depth: 1, min_child_weight: 100, eta: 0.5, threshold: 0.2 => F1 Score: 0.3854380468834396
# max_depth: 1, min_child_weight: 100, eta: 0.5, threshold: 0.3 => F1 Score: 0.3091190108191654
# max_depth: 1, min_child_weight: 100, eta: 0.5, threshold: 0.5 => F1 Score: 0.08489722966934764
# max_depth: 1, min_child_weight: 100, eta: 1, threshold: 0.01 => F1 Score: 0.18629593745071088
# max_depth: 1, min_child_weight: 100, eta: 1, threshold: 0.05 => F1 Score: 0.3080095963634833
# max_depth: 1, min_child_weight: 100, eta: 1, threshold: 0.12 => F1 Score: 0.3933858040291718
# max_depth: 1, min_child_weight: 100, eta: 1, threshold: 0.15 => F1 Score: 0.3999332888592395
# max_depth: 1, min_child_weight: 100, eta: 1, threshold: 0.2 => F1 Score: 0.38837599664288713
# max_depth: 1, min_child_weight: 100, eta: 1, threshold: 0.3 => F1 Score: 0.3571719364907043
# max_depth: 1, min_child_weight: 100, eta: 1, threshold: 0.5 => F1 Score: 0.20077369439071566
# max_depth: 1, min_child_weight: 500, eta: 0.01, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 500, eta: 0.01, threshold: 0.05 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 500, eta: 0.01, threshold: 0.12 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 500, eta: 0.01, threshold: 0.15 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 500, eta: 0.01, threshold: 0.2 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 500, eta: 0.01, threshold: 0.3 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 500, eta: 0.01, threshold: 0.5 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 500, eta: 0.1, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 500, eta: 0.1, threshold: 0.05 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 500, eta: 0.1, threshold: 0.12 => F1 Score: 0.3844541203031769
# max_depth: 1, min_child_weight: 500, eta: 0.1, threshold: 0.15 => F1 Score: 0.31474386263658294
# max_depth: 1, min_child_weight: 500, eta: 0.1, threshold: 0.2 => F1 Score: 0.09689495705791676
# max_depth: 1, min_child_weight: 500, eta: 0.1, threshold: 0.3 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 500, eta: 0.1, threshold: 0.5 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 500, eta: 0.2, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 500, eta: 0.2, threshold: 0.05 => F1 Score: 0.21759752717970582
# max_depth: 1, min_child_weight: 500, eta: 0.2, threshold: 0.12 => F1 Score: 0.3797250859106529
# max_depth: 1, min_child_weight: 500, eta: 0.2, threshold: 0.15 => F1 Score: 0.3756008973400278
# max_depth: 1, min_child_weight: 500, eta: 0.2, threshold: 0.2 => F1 Score: 0.2515918086387885
# max_depth: 1, min_child_weight: 500, eta: 0.2, threshold: 0.3 => F1 Score: 0.048599861143253875
# max_depth: 1, min_child_weight: 500, eta: 0.2, threshold: 0.5 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 500, eta: 0.3, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 500, eta: 0.3, threshold: 0.05 => F1 Score: 0.239600466521128
# max_depth: 1, min_child_weight: 500, eta: 0.3, threshold: 0.12 => F1 Score: 0.36446189716529637
# max_depth: 1, min_child_weight: 500, eta: 0.3, threshold: 0.15 => F1 Score: 0.3877280265339967
# max_depth: 1, min_child_weight: 500, eta: 0.3, threshold: 0.2 => F1 Score: 0.34716406547392464
# max_depth: 1, min_child_weight: 500, eta: 0.3, threshold: 0.3 => F1 Score: 0.20072229614141798
# max_depth: 1, min_child_weight: 500, eta: 0.3, threshold: 0.5 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 500, eta: 0.5, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 500, eta: 0.5, threshold: 0.05 => F1 Score: 0.2729608899214982
# max_depth: 1, min_child_weight: 500, eta: 0.5, threshold: 0.12 => F1 Score: 0.3837101490621211
# max_depth: 1, min_child_weight: 500, eta: 0.5, threshold: 0.15 => F1 Score: 0.39815281276238457
# max_depth: 1, min_child_weight: 500, eta: 0.5, threshold: 0.2 => F1 Score: 0.3854380468834396
# max_depth: 1, min_child_weight: 500, eta: 0.5, threshold: 0.3 => F1 Score: 0.3091190108191654
# max_depth: 1, min_child_weight: 500, eta: 0.5, threshold: 0.5 => F1 Score: 0.08489722966934764
# max_depth: 1, min_child_weight: 500, eta: 1, threshold: 0.01 => F1 Score: 0.18629593745071088
# max_depth: 1, min_child_weight: 500, eta: 1, threshold: 0.05 => F1 Score: 0.3080095963634833
# max_depth: 1, min_child_weight: 500, eta: 1, threshold: 0.12 => F1 Score: 0.3933858040291718
# max_depth: 1, min_child_weight: 500, eta: 1, threshold: 0.15 => F1 Score: 0.3999332888592395
# max_depth: 1, min_child_weight: 500, eta: 1, threshold: 0.2 => F1 Score: 0.38837599664288713
# max_depth: 1, min_child_weight: 500, eta: 1, threshold: 0.3 => F1 Score: 0.3571719364907043
# max_depth: 1, min_child_weight: 500, eta: 1, threshold: 0.5 => F1 Score: 0.20077369439071566
# max_depth: 1, min_child_weight: 1000, eta: 0.01, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 1000, eta: 0.01, threshold: 0.05 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 1000, eta: 0.01, threshold: 0.12 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 1000, eta: 0.01, threshold: 0.15 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 1000, eta: 0.01, threshold: 0.2 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 1000, eta: 0.01, threshold: 0.3 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 1000, eta: 0.01, threshold: 0.5 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 1000, eta: 0.1, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 1000, eta: 0.1, threshold: 0.05 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 1000, eta: 0.1, threshold: 0.12 => F1 Score: 0.3694706606483381
# max_depth: 1, min_child_weight: 1000, eta: 0.1, threshold: 0.15 => F1 Score: 0.2913173227227512
# max_depth: 1, min_child_weight: 1000, eta: 0.1, threshold: 0.2 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 1000, eta: 0.1, threshold: 0.3 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 1000, eta: 0.1, threshold: 0.5 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 1000, eta: 0.2, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 1000, eta: 0.2, threshold: 0.05 => F1 Score: 0.21744458653026427
# max_depth: 1, min_child_weight: 1000, eta: 0.2, threshold: 0.12 => F1 Score: 0.37214989570596274
# max_depth: 1, min_child_weight: 1000, eta: 0.2, threshold: 0.15 => F1 Score: 0.36172024696614863
# max_depth: 1, min_child_weight: 1000, eta: 0.2, threshold: 0.2 => F1 Score: 0.24134384641755227
# max_depth: 1, min_child_weight: 1000, eta: 0.2, threshold: 0.3 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 1000, eta: 0.2, threshold: 0.5 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 1000, eta: 0.3, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 1000, eta: 0.3, threshold: 0.05 => F1 Score: 0.23906095994743287
# max_depth: 1, min_child_weight: 1000, eta: 0.3, threshold: 0.12 => F1 Score: 0.3578509362379146
# max_depth: 1, min_child_weight: 1000, eta: 0.3, threshold: 0.15 => F1 Score: 0.3782362127065012
# max_depth: 1, min_child_weight: 1000, eta: 0.3, threshold: 0.2 => F1 Score: 0.34495714453446047
# max_depth: 1, min_child_weight: 1000, eta: 0.3, threshold: 0.3 => F1 Score: 0.18354912414318356
# max_depth: 1, min_child_weight: 1000, eta: 0.3, threshold: 0.5 => F1 Score: 0.0
# max_depth: 1, min_child_weight: 1000, eta: 0.5, threshold: 0.01 => F1 Score: 0.1691315580690441
# max_depth: 1, min_child_weight: 1000, eta: 0.5, threshold: 0.05 => F1 Score: 0.27304739770406367
# max_depth: 1, min_child_weight: 1000, eta: 0.5, threshold: 0.12 => F1 Score: 0.3842924847664184
# max_depth: 1, min_child_weight: 1000, eta: 0.5, threshold: 0.15 => F1 Score: 0.39841243033271406
# max_depth: 1, min_child_weight: 1000, eta: 0.5, threshold: 0.2 => F1 Score: 0.38393731635651324
# max_depth: 1, min_child_weight: 1000, eta: 0.5, threshold: 0.3 => F1 Score: 0.3072651550208237
# max_depth: 1, min_child_weight: 1000, eta: 0.5, threshold: 0.5 => F1 Score: 0.08900756564307966
# max_depth: 1, min_child_weight: 1000, eta: 1, threshold: 0.01 => F1 Score: 0.18629593745071088
# max_depth: 1, min_child_weight: 1000, eta: 1, threshold: 0
43] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "threshold" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# F1 Score: 0.4068511643604455

# %%
params = {
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',
    'eta': 0.1,
    'max_depth': 20,
    'min_child_weight': 50,
}

model = xgb.train(params, dtrain)

y_pred = model.predict(dtest)
y_pred_binary = [1 if pred > 0.15 else 0 for pred in y_pred]
f1 = f1_score(y_train_test, y_pred_binary)
print(f"F1 Score: {f1}")

y_pred = model.predict(dtest)

submission = pd.read_csv("data/sample_submission.csv")
dsubmission = submission.drop(columns=['TARGET'])
dsubmission = xgb.DMatrix(X_test)
y_pred = model.predict(dsubmission)
submission['TARGET'] = y_pred

submission['TARGET'] = submission['TARGET'].apply(lambda x: 1 if x > 0.15 else 0)
submission.to_csv("submission_de_bg.csv", index=False)
# Out:
# F1 Score: 0.4206067940184977

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import f1_score, precision_recall_curve
from xgboost import XGBClassifier

# ----- 1) helpers
def best_f1_threshold(y_true, y_proba):
    # seuil optimal sur les proba (F1)
    ps, rs, ts = precision_recall_curve(y_true, y_proba)
    f1s = (2*ps*rs)/(ps+rs+1e-12)
    # precision_recall_curve ne retourne pas de seuil pour le dernier point → on aligne
    thresholds = np.r_[ts, 1.0]
    t = thresholds[np.nanargmax(f1s)]
    return float(min(max(t, 0.0), 1.0)), float(np.nanmax(f1s))

def pos_weight(y):
    # ratio négatifs / positifs (utile si dataset déséquilibré)
    n_pos = np.sum(y == 1)
    n_neg = np.sum(y == 0)
    return 1.0 if n_pos == 0 else n_neg / max(n_pos, 1)

# ----- 2) matrices d’entraînement/val déjà prêtes dans ton code:
# X_train_train, y_train_train, X_train_test, y_train_test, X_test

spw = pos_weight(y_train_train)

# Grilles compactes mais utiles
max_depth = [3, 5, 8]
min_child_weight = [1, 5, 10]
learning_rate = [0.03, 0.1]         # (eta)
subsample = [0.8, 1.0]
colsample_bytree = [0.8, 1.0]
reg_lambda = [1.0, 5.0]
reg_alpha = [0.0, 0.1]

best_cfg = None
best_f1 = -1.0
best_thr = 0.5
best_n_estimators = None

for md in max_depth:
    for mcw in min_child_weight:
        for lr in learning_rate:
            for ss in subsample:
                for cs in colsample_bytree:
                    for rl in reg_lambda:
                        for ra in reg_alpha:
                            clf = XGBClassifier(
                                objective="binary:logistic",
                                eval_metric="logloss",
                                tree_method="hist",        # rapide et stable
                                n_estimators=5000,         # grand + early stopping
                                learning_rate=lr,
                                max_depth=md,
                                min_child_weight=mcw,
                                subsample=ss,
                                colsample_bytree=cs,
                                reg_lambda=rl,
                                reg_alpha=ra,
                                scale_pos_weight=spw,      # gère le déséquilibre
                                n_jobs=-1,
                                random_state=42
                            )

                            clf.fit(
                                X_train_train, y_train_train,
                                eval_set=[(X_train_test, y_train_test)],
                                verbose=False,
                            )

                            # proba sur la validation
                            y_proba = clf.predict_proba(X_train_test)[:, 1]

                            # seuil F1 optimal
                            thr, f1_at_thr = best_f1_threshold(y_train_test, y_proba)

                            if f1_at_thr > best_f1:
                                best_f1 = f1_at_thr
                                best_thr = thr
                                best_n_estimators = clf.best_iteration + 1
                                best_cfg = dict(
                                    max_depth=md,
                                    min_child_weight=mcw,
                                    learning_rate=lr,
                                    subsample=ss,
                                    colsample_bytree=cs,
                                    reg_lambda=rl,
                                    reg_alpha=ra,
                                    threshold=thr
                                )
                                print(f"[BEST] F1={best_f1:.4f} @thr={best_thr:.3f} "
                                      f"md={md} mcw={mcw} lr={lr} ss={ss} cs={cs} "
                                      f"rl={rl} ra={ra} n_estimators={best_n_estimators}")

print("Best config:", best_cfg)
print("Best F1 (val):", round(best_f1, 4))
print("Best threshold:", round(best_thr, 3))
print("Best n_estimators:", best_n_estimators)

# ----- 3) réentraînement final sur tout l’entraînement (train+val)
clf_final = XGBClassifier(
    objective="binary:logistic",
    eval_metric="logloss",
    tree_method="hist",
    n_estimators=best_n_estimators,   # fixe au meilleur trouvé
    learning_rate=best_cfg["learning_rate"],
    max_depth=best_cfg["max_depth"],
    min_child_weight=best_cfg["min_child_weight"],
    subsample=best_cfg["subsample"],
    colsample_bytree=best_cfg["colsample_bytree"],
    reg_lambda=best_cfg["reg_lambda"],
    reg_alpha=best_cfg["reg_alpha"],
    scale_pos_weight=spw,
    n_jobs=-1,
    random_state=42
)

# on regroupe train+val pour le fit final
X_full = pd.concat([X_train_train, X_train_test], axis=0)
y_full = pd.concat([y_train_train, y_train_test], axis=0)
clf_final.fit(X_full, y_full, verbose=False)

# ----- 4) F1 val (optionnel si tu veux re-checker) :
y_proba_val = clf_final.predict_proba(X_train_test)[:, 1]
y_pred_val = (y_proba_val >= best_thr).astype(int)
print("F1 (val, final):", f1_score(y_train_test, y_pred_val))

# ----- 5) prédictions test + seuil optimal F1
y_proba_test = clf_final.predict_proba(X_test)[:, 1]
y_pred_test_bin = (y_proba_test >= best_thr).astype(int)

# ----- 6) submission
submission = pd.read_csv("data/sample_submission.csv")
submission["TARGET"] = y_proba_test  # garde les proba si besoin
# ou binaire si requis :
# submission["TARGET"] = y_pred_test_bin
submission.to_csv("submission_de_bg.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[53], line 65
#      47 for ra in reg_alpha:
#      48     clf = XGBClassifier(
#      49         objective="binary:logistic",
#      50         eval_metric="logloss",
#    (...)
#      62         random_state=42
#      63     )
# ---> 65     clf.fit(
#      66         X_train_train, y_train_train,
#      67         eval_set=[(X_train_test, y_train_test)],
#      68         verbose=False,
#      69     )
#      71     # proba sur la validation
#      72     y_proba = clf.predict_proba(X_train_test)[:, 1]
#
# File ~/anaconda3/envs/sdd_env/lib/python3.12/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File ~/anaconda3/envs/sdd_env/lib/python3.12/site-packages/xgboost/sklearn.py:1683, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1661 model, metric, params, feature_weights = self._configure_fit(
#    1662     xgb_model, params, feature_weights
#    1663 )
#    1664 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1665     missing=self.missing,
#    1666     X=X,
#    (...)
#    1680     feature_types=self.feature_types,
#    1681 )
# -> 1683 self._Booster = train(
#    1684     params,
#    1685     train_dmatrix,
#    1686     self.get_num_boosting_rounds(),
#    1687     evals=evals,
#    1688     early_stopping_rounds=self.early_stopping_rounds,
#    1689     evals_result=evals_result,
#    1690     obj=obj,
#    1691     custom_metric=metric,
#    1692     verbose_eval=verbose,
#    1693     xgb_model=model,
#    1694     callbacks=self.callbacks,
#    1695 )
#    1697 if not callable(self.objective):
#    1698     self.objective = params["objective"]
#
# File ~/anaconda3/envs/sdd_env/lib/python3.12/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File ~/anaconda3/envs/sdd_env/lib/python3.12/site-packages/xgboost/training.py:183, in train(params, dtrain, num_boost_round, evals, obj, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     181 if cb_container.before_iteration(bst, i, dtrain, evals):
#     182     break
# --> 183 bst.update(dtrain, iteration=i, fobj=obj)
#     184 if cb_container.after_iteration(bst, i, dtrain, evals):
#     185     break
#
# File ~/anaconda3/envs/sdd_env/lib/python3.12/site-packages/xgboost/core.py:2247, in Booster.update(self, dtrain, iteration, fobj)
#    2243 self._assign_dmatrix_features(dtrain)
#    2245 if fobj is None:
#    2246     _check_call(
# -> 2247         _LIB.XGBoosterUpdateOneIter(
#    2248             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2249         )
#    2250     )
#    2251 else:
#    2252     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
# Génération du dictionnaire .json à partir du HTML
parser = HTMLParser()
html_snippet = "data/USCODE22_LLCP_102523.HTML"

codebook = parser.parse_html_codebook(html_snippet)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Génération du dictionnaire .json à partir du HTML
# ----> 2 parser = HTMLParser()
#       3 html_snippet = "data/USCODE22_LLCP_102523.HTML"
#       5 codebook = parser.parse_html_codebook(html_snippet)
#
# NameError: name 'HTMLParser' is not defined

# %%
config = "features.yaml"

with open(config, 'r') as file:
    config = yaml.load(file, Loader=yaml.FullLoader)

# %%
data_reduced = data[config['features']].copy()

# %%
features_classification = {}

for feature in config['features']:
    features_classification[feature] = {}
    entry = next((item for item in codebook if item["sas_variable"] == feature), None)
    if entry:
        categories = list(set([cat['value'] for cat in entry['categories']]))
        categories.sort()
        if categories[0] != str(1):
            features_classification[feature] = 'numerical'

            print(f"Feature: {feature}")
            print(categories)

        else:
            features_classification[feature] = 'categorical'
    else:
        features_classification[feature] = 'unknown'
# Out:
# Feature: PHYSHLTH
# ['1 - 30', '77', '88', '99', 'BLANK']
# Feature: MENTHLTH
# ['1 - 30', '77', '88', '99', 'BLANK']
# Feature: POORHLTH
# ['1 - 30', '77', '88', '99', 'BLANK']
# Feature: SLEPTIM1
# ['1 - 24', '77', '99', 'BLANK']
# Feature: WEIGHT2
# ['50 - 0776', '7777', '9023 - 9352', '9999', 'BLANK']
# Feature: HEIGHT3
# ['200 - 711', '7777', '9061 - 9998', '9999', 'BLANK']
# Feature: MARIJAN1
# ['1 - 30', '77', '88', '99', 'BLANK']
# Feature: ALCDAY4
# ['101 - 199', '201 - 299', '777', '888', '999', 'BLANK']
# Feature: AVEDRNK3
# ['1 - 76', '77', '88', '99', 'BLANK']
# Feature: DRNK3GE5
# ['1 - 76', '77', '88', '99', 'BLANK']
# Feature: MAXDRNKS
# ['0', '1 - 76', '77', '99', 'BLANK']
# Feature: COPDSMOK
# ['1 - 76', '77', '88', '99', 'BLANK']
# Feature: _PACKDAY
# ['0 - 100', 'BLANK']
# Feature: _CLLCPWT
# ['HIDDEN']

# %%
# Handle missing values for numerical features

continuous_columns = ['PHYSHLTH','MENTHLTH','POORHLTH',
                      'SLEPTIM1','WEIGHT2','HEIGHT3',
                      'MARIJAN1','ALCDAY4','AVEDRNK3','DRNK3GE5',
                      'MAXDRNKS','COPDSMOK','_PACKDAY',
                      ]

data_reduced["_PACKDAY"] = data_reduced["_PACKDAY"].fillna(data_reduced["_PACKDAY"].median())

data_reduced["COPDSMOK"] = data_reduced["COPDSMOK"].replace({88:0, 77:np.nan, 99:np.nan}).fillna(data_reduced["COPDSMOK"].median())

data_reduced["MAXDRNKS"] = data_reduced["MAXDRNKS"].replace({77:np.nan, 99:np.nan}).fillna(data_reduced["MAXDRNKS"].median())

data_reduced["DRNK3GE5"] = data_reduced["DRNK3GE5"].replace({88:0, 77:np.nan, 99:np.nan}).fillna(data_reduced["DRNK3GE5"].median())

data_reduced["AVEDRNK3"] = data_reduced["AVEDRNK3"].replace({88:0, 77:np.nan, 99:np.nan}).fillna(data_reduced["AVEDRNK3"].median())

data_reduced["MARIJAN1"] = data_reduced["MARIJAN1"].replace({88:0, 77:np.nan, 99:np.nan}).fillna(data_reduced["MARIJAN1"].median())

mask_alc_week = data_reduced["ALCDAY4"].astype(float).between(101, 199)
data_reduced.loc[mask_alc_week, "ALCDAY4"] = (data_reduced.loc[mask_alc_week, "ALCDAY4"] % 100) * 4
mask_alc_month = data_reduced["ALCDAY4"].between(201, 299)  
data_reduced.loc[mask_alc_month, "ALCDAY4"] = (data_reduced.loc[mask_alc_month, "ALCDAY4"] % 200)

data_reduced["ALCDAY4"] = data_reduced["ALCDAY4"].replace({888:0, 777:np.nan, 999:np.nan}).fillna(data_reduced["ALCDAY4"].median())

data_reduced["SLEPTIM1"] = data_reduced["SLEPTIM1"].replace({77:np.nan, 99:np.nan}).fillna(data_reduced["SLEPTIM1"].median())

data_reduced["POORHLTH"] = data_reduced["POORHLTH"].replace({88:0, 77:np.nan, 99:np.nan}).fillna(data_reduced["POORHLTH"].median())

data_reduced["MENTHLTH"] = data_reduced["MENTHLTH"].replace({88:0, 77:np.nan, 99:np.nan}).fillna(data_reduced["MENTHLTH"].median())

data_reduced["PHYSHLTH"] = data_reduced["PHYSHLTH"].replace({88:0, 77:np.nan, 99:np.nan}).fillna(data_reduced["PHYSHLTH"].median())

def ft_in_to_cm(s):
    s = str(int(float(s))).zfill(3)  
    feet = int(s[0])
    inches = int(s[1:])
    return feet * 30.48 + inches * 2.54

 
data_reduced["WEIGHT2"] = data_reduced["WEIGHT2"].astype(float)
mask_lb = data_reduced["WEIGHT2"].between(50, 776)
data_reduced.loc[mask_lb, "WEIGHT2"] = data_reduced.loc[mask_lb, "WEIGHT2"] * 0.45359237

mask_kg = data_reduced["WEIGHT2"].between(9023, 9352) 
data_reduced.loc[mask_kg, "WEIGHT2"] = data_reduced.loc[mask_kg, "WEIGHT2"] - 9000

mask_ft_in = data_reduced["HEIGHT3"].astype(float).between(200, 711)
data_reduced.loc[mask_ft_in, "HEIGHT3"] = data_reduced.loc[mask_ft_in, "HEIGHT3"].apply(ft_in_to_cm)

mask_kg = data_reduced["HEIGHT3"].between(9061, 9998)  
data_reduced.loc[mask_kg, "HEIGHT3"] = data_reduced.loc[mask_kg, "HEIGHT3"] - 9000

data_reduced["WEIGHT2"] = data_reduced["WEIGHT2"].replace({7777:np.nan, 9999:np.nan}).fillna(data_reduced["WEIGHT2"].median())

data_reduced["HEIGHT3"] = data_reduced["HEIGHT3"].replace({7777:np.nan, 9999:np.nan}).fillna(data_reduced["HEIGHT3"].median())

# %%
data_reduced[continuous_columns].head()
# Out:
#    PHYSHLTH  MENTHLTH  POORHLTH  SLEPTIM1     WEIGHT2  HEIGHT3  MARIJAN1  \
# 0      30.0       0.0       0.0       7.0   74.842741   157.48      88.0
# 1       0.0      15.0      14.0       6.0   64.863709   157.48      88.0
# 2       0.0       0.0      88.0       8.0  129.273825   180.34      88.0
# 3       0.0       0.0      88.0      10.0  111.130131   182.88      88.0
# 4       0.0       3.0       0.0       7.0   81.646627   185.42      88.0
#
#    ALCDAY4  AVEDRNK3  DRNK3GE5  MAXDRNKS  COPDSMOK  _PACKDAY
# 0      8.0       1.0       0.0       2.0      88.0      2.00
# 1     30.0       2.0      88.0       2.0      88.0      0.50
# 2      0.0       2.0      88.0       2.0      88.0      0.75
# 3      0.0       2.0      88.0       2.0      88.0      0.50
# 4      5.0       4.0       2.0       7.0      88.0      0.50

# %%
categorical_features = [feat for feat, info in features_classification.items() if info == 'categorical']

data_reduced[categorical_features] = data_reduced[categorical_features].fillna(-1)
data_reduced[categorical_features] = (
    data_reduced[categorical_features].astype('category').apply(lambda x: x.cat.codes)
)

# %%
data_reduced = data_reduced.set_index('ID')

# %%
data_reduced
# Out:
#         _STATE  GENHLTH  PHYSHLTH  MENTHLTH  POORHLTH  PRIMINSR  PERSDOC3  \
# ID
# 0            1        3  1.518224 -0.419364 -1.008502         3         1
# 1            6        3 -0.409570  0.623837 -0.671989        10         2
# 2           15        2 -0.409570 -0.419364  1.106724         1         1
# 3           35        3 -0.409570 -0.419364  1.106724         1         3
# 4           21        3 -0.409570 -0.210724 -1.008502         9         2
# ...        ...      ...       ...       ...       ...       ...       ...
# 224995       1        3 -0.409570 -0.419364  1.106724         3         2
# 224996      13        3  0.554327  0.623837 -0.647952         2         3
# 224997      34        3 -0.409570 -0.419364  1.106724         1         3
# 224998      21        1  0.233028 -0.419364 -0.888319         9         1
# 224999       2        2 -0.409570 -0.419364  1.106724        10         1
#
#         MEDCOST1  CHECKUP1  EXERANY2  ...  _AGEG5YR  _CURECI2  _PACKDAY  \
# ID                                    ...
# 0              2         1         1  ...        12         0  3.550165
# 1              2         3         2  ...         2         0 -0.233186
# 2              2         1         1  ...         4         0  0.397373
# 3              2         1         1  ...         7         0 -0.233186
# 4              2         1         1  ...         0         0 -0.233186
# ...          ...       ...       ...  ...       ...       ...       ...
# 224995         2         1         1  ...        10         0  1.027931
# 224996         1         4         2  ...         8         0  0.397373
# 224997         2         1         1  ...         6         0 -0.233186
# 224998         2         1         1  ...         7         0 -0.233186
# 224999         2         1         1  ...        12         0  0.397373
#
#         _SMOKGRP  _LCSREC  _RFDRHV8  _FLSHOT7  _PNEUMO3  TARGET  _CLLCPWT
# ID
# 0              3        0         0         1         1    True       NaN
# 1              4        0         2         0         0   False       NaN
# 2              3        0         0         0         0   False       NaN
# 3              4        0         0         0         0   False       NaN
# 4              4        0         0         0         0   False       NaN
# ...          ...      ...       ...       ...       ...     ...       ...
# 224995         2        2         0         2         3    True       NaN
# 224996         3        0         0         0         0   False       NaN
# 224997         4        0         0         0         0   False       NaN
# 224998         4        0         0         0         0   False       NaN
# 224999         3        0         0         1         1   False       NaN
#
# [225000 rows x 77 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

data_reduced[continuous_columns] = scaler.fit_transform(data_reduced[continuous_columns])

# %%
X = data_reduced.drop('TARGET', axis = 1)
y = data_reduced['TARGET'].astype(int)

# %%
from sklearn.feature_selection import mutual_info_classif

mi = mutual_info_classif(X, y, discrete_features='auto', random_state=42)
mi_series = pd.Series(mi, index=X.columns).sort_values(ascending=False)

plt.figure(figsize=(12,6))
mi_series.plot(kind='bar')
plt.ylabel('Mutual Information')
plt.title('Importance des features par rapport au label')
plt.show()


mi_cumsum = mi_series.cumsum()
mi_total = mi_series.sum()

threshold = 0.99 * mi_total
features_99 = mi_cumsum[mi_cumsum <= threshold].index.tolist()

print("Nombre de features conservées :", len(features_99))
print("Features conservées :", features_99)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 3
#       1 from sklearn.feature_selection import mutual_info_classif
# ----> 3 mi = mutual_info_classif(X, y, discrete_features='auto', random_state=42)
#       4 mi_series = pd.Series(mi, index=X.columns).sort_values(ascending=False)
#       6 plt.figure(figsize=(12,6))
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/sklearn/feature_selection/_mutual_info.py:571, in mutual_info_classif(X, y, discrete_features, n_neighbors, copy, random_state, n_jobs)
#     475 """Estimate mutual information for a discrete target variable.
#     476
#     477 Mutual information (MI) [1]_ between two random variables is a non-negative
#    (...)
#     568        0.   , 0.   , 0.   , 0.     , 0.])
#     569 """
#     570 check_classification_targets(y)
# --> 571 return _estimate_mi(
#     572     X,
#     573     y,
#     574     discrete_features=discrete_features,
#     575     discrete_target=True,
#     576     n_neighbors=n_neighbors,
#     577     copy=copy,
#     578     random_state=random_state,
#     579     n_jobs=n_jobs,
#     580 )
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/sklearn/feature_selection/_mutual_info.py:271, in _estimate_mi(X, y, discrete_features, discrete_target, n_neighbors, copy, random_state, n_jobs)
#     202 def _estimate_mi(
#     203     X,
#     204     y,
#    (...)
#     211     n_jobs=None,
#     212 ):
#     213     """Estimate mutual information between the features and the target.
#     214
#     215     Parameters
#    (...)
#     269            Data Sets". PLoS ONE 9(2), 2014.
#     270     """
# --> 271     X, y = check_X_y(X, y, accept_sparse="csc", y_numeric=not discrete_target)
#     272     n_samples, n_features = X.shape
#     274     if isinstance(discrete_features, (str, bool)):
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/sklearn/utils/validation.py:1368, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1362     raise ValueError(
#    1363         f"{estimator_name} requires y to be passed, but the target y is None"
#    1364     )
#    1366 ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
# -> 1368 X = check_array(
#    1369     X,
#    1370     accept_sparse=accept_sparse,
#    1371     accept_large_sparse=accept_large_sparse,
#    1372     dtype=dtype,
#    1373     order=order,
#    1374     copy=copy,
#    1375     force_writeable=force_writeable,
#    1376     ensure_all_finite=ensure_all_finite,
#    1377     ensure_2d=ensure_2d,
#    1378     allow_nd=allow_nd,
#    1379     ensure_min_samples=ensure_min_samples,
#    1380     ensure_min_features=ensure_min_features,
#    1381     estimator=estimator,
#    1382     input_name="X",
#    1383 )
#    1385 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1387 check_consistent_length(X, y)
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/sklearn/utils/validation.py:1105, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1099     raise ValueError(
#    1100         f"Found array with dim {array.ndim},"
#    1101         f" while dim <= 2 is required{context}."
#    1102     )
#    1104 if ensure_all_finite:
# -> 1105     _assert_all_finite(
#    1106         array,
#    1107         input_name=input_name,
#    1108         estimator_name=estimator_name,
#    1109         allow_nan=ensure_all_finite == "allow-nan",
#    1110     )
#    1112 if copy:
#    1113     if _is_numpy_namespace(xp):
#    1114         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/sklearn/utils/validation.py:120, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     117 if first_pass_isfinite:
#     118     return
# --> 120 _assert_all_finite_element_wise(
#     121     X,
#     122     xp=xp,
#     123     allow_nan=allow_nan,
#     124     msg_dtype=msg_dtype,
#     125     estimator_name=estimator_name,
#     126     input_name=input_name,
#     127 )
#
# File ~/anaconda3/envs/myenv/lib/python3.12/site-packages/sklearn/utils/validation.py:169, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     152 if estimator_name and input_name == "X" and has_nan_error:
#     153     # Improve the error message on how to handle missing values in
#     154     # scikit-learn.
#     155     msg_err += (
#     156         f"\n{estimator_name} does not accept missing values"
#     157         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     167         "#estimators-that-handle-nan-values"
#     168     )
# --> 169 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.

# %%
from xgboost import XGBClassifier
from sklearn.metrics import f1_score

xgb =  XGBClassifier()

xgb.fit(X, y)

y_pred = xgb.predict(X)
print(f1_score(y_pred, y))
# Out:
# 0.3033774442030417

# %%
importances = xgb.feature_importances_
indices = np.argsort(importances)[::-1]


plt.figure(figsize=(20,8))
plt.title("Feature importances")
plt.bar(range(X.shape[1]), importances[indices], color="r", align="center")
plt.xticks(range(X.shape[1]), indices, rotation = 90)
plt.xlim([-1, X.shape[1]])
plt.show()

mi_cumsum = importances[indices].cumsum()
mi_total = importances[indices].sum()

threshold = 0.99 * mi_total
features_99 = mi_cumsum[mi_cumsum <= threshold]
indice = indices[mi_cumsum <= threshold]
print("Nombre de features conservées :", len(features_99))
print("Features conservées :", indice)
# Out:
# Nombre de features conservées : 70
# Features conservées : [ 1 67 11 42 66 41 16 24 17 14 71 33  6 21  8 69 64 70  2  5 15  7 72 12
#  13 50 43 23 63 51 19 18 37 65 26 10  3 39 68 55 58  0 27 44 46 49 62 45
#  74 20 36 73 34 38 32 22 47 30 25 31 28 56  4 40 35 52 48 29  9 59]
